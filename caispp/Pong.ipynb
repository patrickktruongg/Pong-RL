# %%
## Architecture

# Take in inputs from the screen and preprocess them
# Pass them into an NN
# Update the weights of the NN using gradient descent
# weights['1'] - Matrix that holds weights of pixels passing into hidden layer. Dimensions: [200 x 80 x 80] -> [200 x 6400]
# weights['2'] - Matrix that holds weights of hidden layer passing into output. Dimensions: [1 x 200]

# Process is:

# processed_observations = image vector - [6400 x 1] array
# Compute hidden_layer_values = weights['1'] dot processed_observations ([200 x 6400] dot [6400 x 1]) -> [200 x 1] - this gives initial activation values.
# Next we need to transform those using ReLU
# ReLU(hidden_layer_values)
# Next we need to pass this one layer further
# output_layer_value = weights['2'] dot hidden_layer_values ([1 x 200] dot [200 x 1] -> [1 x 1])
# Now our output layer is the probability of going up or down. Let's make sure this output is between 0 and 1 by passing it through a sigmoid
# p = sigmoid(output_layer_value)

# Learning after round has finished:

# Figure out the result
# Compute the error
# Use the error to calculate the gradient
    # The below dimensions all assume we had exactly 10 frames in the round (not necessarily true!)
    # dC_dw2 = hidden_layer_values^T dot gradient_log_p ([1 x 2000] dot [2000 x 1] -> 1x1)
    # delta_1 = gradient_log_p outer_product weights['2'] = [2000 x 1] outer_product [1 x 200] ([2000 x 200])
    # dC_dw1 = delta_1^T dot input_observations ([200 x 2000]x dot [2000 x 64000] -> [200 x 64000])

# After some batch size of rounds has finished,
    # Use rmsprop to move weights['1'] and weights['2'] in the direction of the gradient
# Repeat!

import gym
import numpy as np

def downsample(image):
    # Take only alternate pixels - basically halves the resolution of the image (which is fine for us)
    return image[::2, ::2, :]

def remove_color(image):
    """Convert all color (RGB is the third dimension in the image)"""
    return image[:, :, 0]

def remove_background(image):
    image[image == 144] = 0
    image[image == 109] = 0
    return image

def preprocess_observations(input_observation, prev_processed_observation, input_dimensions):
    """ convert the 210x160x3 uint8 frame into a 6400 float vector """
    # 1. Crop the immage
    # 2. Downsample the image.
    # 3. Convert the image to black and white (color is not particularly important to us).
    # 4. Remove the background.
    # 5. Convert from an 80 x 80 matrix of values to 6400 x 1 matrix (flatten the matrix so it’s easier to use).
    # 6. Store just the difference between the current frame and the previous frame if we know the previous frame (we only care about what’s changed).
    
    processed_observation = input_observation[35:195] # crop
    processed_observation = downsample(processed_observation)
    processed_observation = remove_color(processed_observation)
    processed_observation = remove_background(processed_observation)
    processed_observation[processed_observation != 0] = 1 # everything else (paddles, ball) just set to 1
    # Convert from 80 x 80 matrix to 1600 x 1 matrix
    processed_observation = processed_observation.astype(np.float).ravel()

    # subtract the previous frame from the current one so we are only processing on changes in the game
    if prev_processed_observation is not None:
        input_observation = processed_observation - prev_processed_observation
    else:
        input_observation = np.zeros(input_dimensions)
    # store the previous frame so we can subtract from it next time
    prev_processed_observations = processed_observation
    return input_observation, prev_processed_observations


def sigmoid(x):
    return 1.0/(1.0 + np.exp(-x))

def relu(vector):
    vector[vector < 0] = 0
    return vector

def apply_neural_nets(observation_matrix, weights):
    """ Based on the observation_matrix and weights, compute the new hidden layer values and the new output layer values"""
    hidden_layer_values = np.dot(weights['1'], observation_matrix)
    hidden_layer_values = relu(hidden_layer_values)
    output_layer_values = np.dot(hidden_layer_values, weights['2'])
    output_layer_values = sigmoid(output_layer_values)
    return hidden_layer_values, output_layer_values

def choose_action(probability):
    random_value = np.random.uniform()
    if random_value < probability:
        # signifies up in openai gym
        return 2
    else:
         # signifies down in openai gym
        return 3

def compute_gradient(gradient_log_p, hidden_layer_values, observation_values, weights):
    """ See here: http://neuralnetworksanddeeplearning.com/chap2.html"""
    delta_L = gradient_log_p
    dC_dw2 = np.dot(hidden_layer_values.T, delta_L).ravel()
    delta_l2 = np.outer(delta_L, weights['2'])
    delta_l2 = relu(delta_l2)
    dC_dw1 = np.dot(delta_l2.T, observation_values)
    return {
        '1': dC_dw1,
        '2': dC_dw2
    }

def update_weights(weights, expectation_g_squared, g_dict, decay_rate, learning_rate):
    """ See here: http://sebastianruder.com/optimizing-gradient-descent/index.html#rmsprop"""
    epsilon = 1e-5
    for layer_name in weights.keys():
        g = g_dict[layer_name]
        expectation_g_squared[layer_name] = decay_rate * expectation_g_squared[layer_name] + (1 - decay_rate) * g**2
        weights[layer_name] += (learning_rate * g)/(np.sqrt(expectation_g_squared[layer_name] + epsilon))
        g_dict[layer_name] = np.zeros_like(weights[layer_name]) # reset batch gradient buffer

def discount_rewards(rewards, gamma):
    """ Actions you took 20 steps before the end result are less important to the overall result than an action you took a step ago.
    This implements that logic by discounting the reward on previous actions based on how long ago they were taken"""
    discounted_rewards = np.zeros_like(rewards)
    running_add = 0
    for t in reversed(range(0, rewards.size)):
        if rewards[t] != 0:
            running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
        running_add = running_add * gamma + rewards[t]
        discounted_rewards[t] = running_add
    return discounted_rewards

def discount_with_rewards(gradient_log_p, episode_rewards, gamma):
    """ discount the gradient with the normalized rewards """
    discounted_episode_rewards = discount_rewards(episode_rewards, gamma)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_episode_rewards -= np.mean(discounted_episode_rewards)
    discounted_episode_rewards /= np.std(discounted_episode_rewards)
    return gradient_log_p * discounted_episode_rewards


def main():
    env = gym.make("Pong-v0")
    observation = env.reset() # This gets us the image

    # hyperparameters
    episode_number = 0
    batch_size = 10 #how many rounds we play before updating the weights of our network
    gamma = 0.99 # discount factor for reward
    decay_rate = 0.99 # for RMSProp algorithm
    num_hidden_layer_neurons = 200
    input_dimensions = 80 * 80
    learning_rate = 1e-4 # rate at which we learn from results --> higher rate, more reaction to results, lower rate, less reaction to results
    
    episode_number = 0
    reward_sum = 0
    running_reward = None
    prev_processed_observations = None

    weights = {
        '1': np.random.randn(num_hidden_layer_neurons, input_dimensions) / np.sqrt(input_dimensions),
        '2': np.random.randn(num_hidden_layer_neurons) / np.sqrt(num_hidden_layer_neurons)
    }

    # To be used with rmsprop algorithm (http://sebastianruder.com/optimizing-gradient-descent/index.html#rmsprop)
    expectation_g_squared = {}
    g_dict = {}
    for layer_name in weights.keys():
        expectation_g_squared[layer_name] = np.zeros_like(weights[layer_name])
        g_dict[layer_name] = np.zeros_like(weights[layer_name])

    episode_hidden_layer_values, episode_observations, episode_gradient_log_ps, episode_rewards = [], [], [], []


    while True:
        env.render()
        processed_observations, prev_processed_observations = preprocess_observations(observation, prev_processed_observations, input_dimensions)
        hidden_layer_values, up_probability = apply_neural_nets(processed_observations, weights)
    
        episode_observations.append(processed_observations)
        episode_hidden_layer_values.append(hidden_layer_values)

        action = choose_action(up_probability)

        # carry out the chosen action
        observation, reward, done, info = env.step(action)

        reward_sum += reward
        episode_rewards.append(reward)

        # see here: http://cs231n.github.io/neural-networks-2/#losses
        fake_label = 1 if action == 2 else 0
        loss_function_gradient = fake_label - up_probability
        episode_gradient_log_ps.append(loss_function_gradient)


        if done: # an episode finished
            episode_number += 1

            # Combine the following values for the episode
            episode_hidden_layer_values = np.vstack(episode_hidden_layer_values)
            episode_observations = np.vstack(episode_observations)
            episode_gradient_log_ps = np.vstack(episode_gradient_log_ps)
            episode_rewards = np.vstack(episode_rewards)

            # Tweak the gradient of the log_ps based on the discounted rewards
            episode_gradient_log_ps_discounted = discount_with_rewards(episode_gradient_log_ps, episode_rewards, gamma)

            gradient = compute_gradient(
              episode_gradient_log_ps_discounted,
              episode_hidden_layer_values,
              episode_observations,
              weights
            )

            # Sum the gradient for use when we hit the batch size
            for layer_name in gradient:
                g_dict[layer_name] += gradient[layer_name]

            if episode_number % batch_size == 0:
                update_weights(weights, expectation_g_squared, g_dict, decay_rate, learning_rate)

            episode_hidden_layer_values, episode_observations, episode_gradient_log_ps, episode_rewards = [], [], [], [] # reset values
            observation = env.reset() # reset env
            running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
            print("Episode: %d, episode reward total was %f, running mean: %f" % (episode_number, reward_sum, running_reward))
            reward_sum = 0
            prev_processed_observations = None

main()
# Out:
# resetting env. episode reward total was -20.000000. running mean: -20.000000
# resetting env. episode reward total was -17.000000. running mean: -19.970000
# resetting env. episode reward total was -21.000000. running mean: -19.980300
# resetting env. episode reward total was -21.000000. running mean: -19.990497
# resetting env. episode reward total was -19.000000. running mean: -19.980592
# resetting env. episode reward total was -21.000000. running mean: -19.990786
# resetting env. episode reward total was -20.000000. running mean: -19.990878
# resetting env. episode reward total was -20.000000. running mean: -19.990969
# resetting env. episode reward total was -21.000000. running mean: -20.001060
# resetting env. episode reward total was -21.000000. running mean: -20.011049
# resetting env. episode reward total was -21.000000. running mean: -20.020939
# resetting env. episode reward total was -21.000000. running mean: -20.030729
# resetting env. episode reward total was -20.000000. running mean: -20.030422
# resetting env. episode reward total was -21.000000. running mean: -20.040118
# resetting env. episode reward total was -21.000000. running mean: -20.049717
# resetting env. episode reward total was -21.000000. running mean: -20.059219
# resetting env. episode reward total was -21.000000. running mean: -20.068627
# resetting env. episode reward total was -21.000000. running mean: -20.077941
# resetting env. episode reward total was -21.000000. running mean: -20.087162
# resetting env. episode reward total was -21.000000. running mean: -20.096290
# resetting env. episode reward total was -21.000000. running mean: -20.105327
# resetting env. episode reward total was -21.000000. running mean: -20.114274
# resetting env. episode reward total was -20.000000. running mean: -20.113131
# resetting env. episode reward total was -21.000000. running mean: -20.122000
# resetting env. episode reward total was -19.000000. running mean: -20.110780
# resetting env. episode reward total was -20.000000. running mean: -20.109672
# resetting env. episode reward total was -20.000000. running mean: -20.108575
# resetting env. episode reward total was -21.000000. running mean: -20.117489
# resetting env. episode reward total was -21.000000. running mean: -20.126315
# resetting env. episode reward total was -19.000000. running mean: -20.115051
# resetting env. episode reward total was -21.000000. running mean: -20.123901
# resetting env. episode reward total was -20.000000. running mean: -20.122662
# resetting env. episode reward total was -21.000000. running mean: -20.131435
# resetting env. episode reward total was -21.000000. running mean: -20.140121
# resetting env. episode reward total was -21.000000. running mean: -20.148720
# resetting env. episode reward total was -21.000000. running mean: -20.157233
# resetting env. episode reward total was -21.000000. running mean: -20.165660
# resetting env. episode reward total was -21.000000. running mean: -20.174004
# resetting env. episode reward total was -19.000000. running mean: -20.162264
# resetting env. episode reward total was -21.000000. running mean: -20.170641
# resetting env. episode reward total was -21.000000. running mean: -20.178935
# resetting env. episode reward total was -21.000000. running mean: -20.187145
# resetting env. episode reward total was -21.000000. running mean: -20.195274
# resetting env. episode reward total was -21.000000. running mean: -20.203321
# resetting env. episode reward total was -21.000000. running mean: -20.211288
# resetting env. episode reward total was -21.000000. running mean: -20.219175
# resetting env. episode reward total was -20.000000. running mean: -20.216983
# resetting env. episode reward total was -20.000000. running mean: -20.214813
# resetting env. episode reward total was -20.000000. running mean: -20.212665
# resetting env. episode reward total was -21.000000. running mean: -20.220539
# resetting env. episode reward total was -21.000000. running mean: -20.228333
# resetting env. episode reward total was -20.000000. running mean: -20.226050
# resetting env. episode reward total was -19.000000. running mean: -20.213789
# resetting env. episode reward total was -20.000000. running mean: -20.211651
# resetting env. episode reward total was -18.000000. running mean: -20.189535
# resetting env. episode reward total was -19.000000. running mean: -20.177640
# resetting env. episode reward total was -20.000000. running mean: -20.175863
# resetting env. episode reward total was -19.000000. running mean: -20.164105
# resetting env. episode reward total was -20.000000. running mean: -20.162463
# resetting env. episode reward total was -21.000000. running mean: -20.170839
# resetting env. episode reward total was -21.000000. running mean: -20.179130
# resetting env. episode reward total was -21.000000. running mean: -20.187339
# resetting env. episode reward total was -19.000000. running mean: -20.175466
# resetting env. episode reward total was -21.000000. running mean: -20.183711
# resetting env. episode reward total was -21.000000. running mean: -20.191874
# resetting env. episode reward total was -20.000000. running mean: -20.189955
# resetting env. episode reward total was -20.000000. running mean: -20.188056
# resetting env. episode reward total was -21.000000. running mean: -20.196175
# resetting env. episode reward total was -21.000000. running mean: -20.204213
# resetting env. episode reward total was -21.000000. running mean: -20.212171
# resetting env. episode reward total was -21.000000. running mean: -20.220050
# resetting env. episode reward total was -19.000000. running mean: -20.207849
# resetting env. episode reward total was -21.000000. running mean: -20.215771
# resetting env. episode reward total was -21.000000. running mean: -20.223613
# resetting env. episode reward total was -20.000000. running mean: -20.221377
# resetting env. episode reward total was -20.000000. running mean: -20.219163
# resetting env. episode reward total was -21.000000. running mean: -20.226971
# resetting env. episode reward total was -20.000000. running mean: -20.224702
# resetting env. episode reward total was -18.000000. running mean: -20.202455
# resetting env. episode reward total was -20.000000. running mean: -20.200430
# resetting env. episode reward total was -20.000000. running mean: -20.198426
# resetting env. episode reward total was -20.000000. running mean: -20.196441
# resetting env. episode reward total was -21.000000. running mean: -20.204477
# resetting env. episode reward total was -21.000000. running mean: -20.212432
# resetting env. episode reward total was -21.000000. running mean: -20.220308
# resetting env. episode reward total was -21.000000. running mean: -20.228105
# resetting env. episode reward total was -21.000000. running mean: -20.235824
# resetting env. episode reward total was -20.000000. running mean: -20.233466
# resetting env. episode reward total was -19.000000. running mean: -20.221131
# resetting env. episode reward total was -20.000000. running mean: -20.218920
# resetting env. episode reward total was -19.000000. running mean: -20.206730
# resetting env. episode reward total was -20.000000. running mean: -20.204663
# resetting env. episode reward total was -18.000000. running mean: -20.182617
# resetting env. episode reward total was -21.000000. running mean: -20.190790
# resetting env. episode reward total was -21.000000. running mean: -20.198882
# resetting env. episode reward total was -21.000000. running mean: -20.206894
# resetting env. episode reward total was -20.000000. running mean: -20.204825
# resetting env. episode reward total was -20.000000. running mean: -20.202776
# resetting env. episode reward total was -21.000000. running mean: -20.210749
# resetting env. episode reward total was -21.000000. running mean: -20.218641
# resetting env. episode reward total was -20.000000. running mean: -20.216455
# resetting env. episode reward total was -21.000000. running mean: -20.224290
# resetting env. episode reward total was -21.000000. running mean: -20.232047
# resetting env. episode reward total was -21.000000. running mean: -20.239727
# resetting env. episode reward total was -21.000000. running mean: -20.247330
# resetting env. episode reward total was -21.000000. running mean: -20.254856
# resetting env. episode reward total was -21.000000. running mean: -20.262308
# resetting env. episode reward total was -20.000000. running mean: -20.259685
# resetting env. episode reward total was -21.000000. running mean: -20.267088
# resetting env. episode reward total was -20.000000. running mean: -20.264417
# resetting env. episode reward total was -21.000000. running mean: -20.271773
# resetting env. episode reward total was -21.000000. running mean: -20.279055
# resetting env. episode reward total was -20.000000. running mean: -20.276264
# resetting env. episode reward total was -21.000000. running mean: -20.283502
# resetting env. episode reward total was -21.000000. running mean: -20.290667
# resetting env. episode reward total was -21.000000. running mean: -20.297760
# resetting env. episode reward total was -20.000000. running mean: -20.294783
# resetting env. episode reward total was -20.000000. running mean: -20.291835
# resetting env. episode reward total was -19.000000. running mean: -20.278916
# resetting env. episode reward total was -21.000000. running mean: -20.286127
# resetting env. episode reward total was -21.000000. running mean: -20.293266
# resetting env. episode reward total was -21.000000. running mean: -20.300333
# resetting env. episode reward total was -21.000000. running mean: -20.307330
# resetting env. episode reward total was -21.000000. running mean: -20.314257
# resetting env. episode reward total was -20.000000. running mean: -20.311114
# resetting env. episode reward total was -20.000000. running mean: -20.308003
# resetting env. episode reward total was -21.000000. running mean: -20.314923
# resetting env. episode reward total was -19.000000. running mean: -20.301774
# resetting env. episode reward total was -21.000000. running mean: -20.308756
# resetting env. episode reward total was -21.000000. running mean: -20.315668
# resetting env. episode reward total was -21.000000. running mean: -20.322512
# resetting env. episode reward total was -19.000000. running mean: -20.309287
# resetting env. episode reward total was -19.000000. running mean: -20.296194
# resetting env. episode reward total was -20.000000. running mean: -20.293232
# resetting env. episode reward total was -20.000000. running mean: -20.290299
# resetting env. episode reward total was -19.000000. running mean: -20.277396
# resetting env. episode reward total was -21.000000. running mean: -20.284623
# resetting env. episode reward total was -21.000000. running mean: -20.291776
# resetting env. episode reward total was -20.000000. running mean: -20.288859
# resetting env. episode reward total was -21.000000. running mean: -20.295970
# resetting env. episode reward total was -21.000000. running mean: -20.303010
# resetting env. episode reward total was -20.000000. running mean: -20.299980
# resetting env. episode reward total was -20.000000. running mean: -20.296980
# resetting env. episode reward total was -21.000000. running mean: -20.304011
# resetting env. episode reward total was -20.000000. running mean: -20.300970
# resetting env. episode reward total was -21.000000. running mean: -20.307961
# resetting env. episode reward total was -21.000000. running mean: -20.314881
# resetting env. episode reward total was -21.000000. running mean: -20.321732
# resetting env. episode reward total was -21.000000. running mean: -20.328515
# resetting env. episode reward total was -21.000000. running mean: -20.335230
# resetting env. episode reward total was -20.000000. running mean: -20.331878
# resetting env. episode reward total was -18.000000. running mean: -20.308559
# resetting env. episode reward total was -21.000000. running mean: -20.315473
# resetting env. episode reward total was -20.000000. running mean: -20.312318
# resetting env. episode reward total was -21.000000. running mean: -20.319195
# resetting env. episode reward total was -21.000000. running mean: -20.326003
# resetting env. episode reward total was -21.000000. running mean: -20.332743
# resetting env. episode reward total was -21.000000. running mean: -20.339416
# resetting env. episode reward total was -21.000000. running mean: -20.346022
# resetting env. episode reward total was -21.000000. running mean: -20.352561
# resetting env. episode reward total was -21.000000. running mean: -20.359036
# resetting env. episode reward total was -20.000000. running mean: -20.355445
# resetting env. episode reward total was -21.000000. running mean: -20.361891
# resetting env. episode reward total was -20.000000. running mean: -20.358272
# resetting env. episode reward total was -20.000000. running mean: -20.354689
# resetting env. episode reward total was -20.000000. running mean: -20.351143
# resetting env. episode reward total was -21.000000. running mean: -20.357631
# resetting env. episode reward total was -21.000000. running mean: -20.364055
# resetting env. episode reward total was -21.000000. running mean: -20.370414
# resetting env. episode reward total was -21.000000. running mean: -20.376710
# resetting env. episode reward total was -21.000000. running mean: -20.382943
# resetting env. episode reward total was -21.000000. running mean: -20.389114
# resetting env. episode reward total was -20.000000. running mean: -20.385222
# resetting env. episode reward total was -21.000000. running mean: -20.391370
# resetting env. episode reward total was -21.000000. running mean: -20.397456
# resetting env. episode reward total was -21.000000. running mean: -20.403482
# resetting env. episode reward total was -20.000000. running mean: -20.399447
# resetting env. episode reward total was -20.000000. running mean: -20.395453
# resetting env. episode reward total was -21.000000. running mean: -20.401498
# resetting env. episode reward total was -21.000000. running mean: -20.407483
# resetting env. episode reward total was -19.000000. running mean: -20.393408
# resetting env. episode reward total was -21.000000. running mean: -20.399474
# resetting env. episode reward total was -20.000000. running mean: -20.395479
# resetting env. episode reward total was -21.000000. running mean: -20.401525
# resetting env. episode reward total was -20.000000. running mean: -20.397509
# resetting env. episode reward total was -20.000000. running mean: -20.393534
# resetting env. episode reward total was -21.000000. running mean: -20.399599
# resetting env. episode reward total was -21.000000. running mean: -20.405603
# resetting env. episode reward total was -21.000000. running mean: -20.411547
# resetting env. episode reward total was -18.000000. running mean: -20.387431
# resetting env. episode reward total was -20.000000. running mean: -20.383557
# resetting env. episode reward total was -21.000000. running mean: -20.389722
# resetting env. episode reward total was -21.000000. running mean: -20.395824
# resetting env. episode reward total was -20.000000. running mean: -20.391866
# resetting env. episode reward total was -21.000000. running mean: -20.397947
# resetting env. episode reward total was -21.000000. running mean: -20.403968
# resetting env. episode reward total was -21.000000. running mean: -20.409928
# resetting env. episode reward total was -21.000000. running mean: -20.415829
# resetting env. episode reward total was -21.000000. running mean: -20.421671
# resetting env. episode reward total was -21.000000. running mean: -20.427454
# resetting env. episode reward total was -21.000000. running mean: -20.433180
# resetting env. episode reward total was -20.000000. running mean: -20.428848
# resetting env. episode reward total was -20.000000. running mean: -20.424559
# resetting env. episode reward total was -21.000000. running mean: -20.430314
# resetting env. episode reward total was -21.000000. running mean: -20.436011
# resetting env. episode reward total was -20.000000. running mean: -20.431650
# resetting env. episode reward total was -21.000000. running mean: -20.437334
# resetting env. episode reward total was -20.000000. running mean: -20.432961
# resetting env. episode reward total was -19.000000. running mean: -20.418631
# resetting env. episode reward total was -19.000000. running mean: -20.404445
# resetting env. episode reward total was -21.000000. running mean: -20.410400
# resetting env. episode reward total was -20.000000. running mean: -20.406296
# resetting env. episode reward total was -20.000000. running mean: -20.402233
# resetting env. episode reward total was -21.000000. running mean: -20.408211
# resetting env. episode reward total was -20.000000. running mean: -20.404129
# resetting env. episode reward total was -21.000000. running mean: -20.410088
# resetting env. episode reward total was -20.000000. running mean: -20.405987
# resetting env. episode reward total was -19.000000. running mean: -20.391927
# resetting env. episode reward total was -21.000000. running mean: -20.398007
# resetting env. episode reward total was -21.000000. running mean: -20.404027
# resetting env. episode reward total was -20.000000. running mean: -20.399987
# resetting env. episode reward total was -21.000000. running mean: -20.405987
# resetting env. episode reward total was -20.000000. running mean: -20.401927
# resetting env. episode reward total was -21.000000. running mean: -20.407908
# resetting env. episode reward total was -21.000000. running mean: -20.413829
# resetting env. episode reward total was -21.000000. running mean: -20.419691
# resetting env. episode reward total was -21.000000. running mean: -20.425494
# resetting env. episode reward total was -20.000000. running mean: -20.421239
# resetting env. episode reward total was -21.000000. running mean: -20.427027
# resetting env. episode reward total was -21.000000. running mean: -20.432756
# resetting env. episode reward total was -21.000000. running mean: -20.438429
# resetting env. episode reward total was -21.000000. running mean: -20.444044
# resetting env. episode reward total was -21.000000. running mean: -20.449604
# resetting env. episode reward total was -21.000000. running mean: -20.455108
# resetting env. episode reward total was -21.000000. running mean: -20.460557
# resetting env. episode reward total was -21.000000. running mean: -20.465951
# resetting env. episode reward total was -21.000000. running mean: -20.471292
# resetting env. episode reward total was -21.000000. running mean: -20.476579
# resetting env. episode reward total was -21.000000. running mean: -20.481813
# resetting env. episode reward total was -21.000000. running mean: -20.486995
# resetting env. episode reward total was -21.000000. running mean: -20.492125
# resetting env. episode reward total was -21.000000. running mean: -20.497204
# resetting env. episode reward total was -20.000000. running mean: -20.492232
# resetting env. episode reward total was -21.000000. running mean: -20.497309
# resetting env. episode reward total was -21.000000. running mean: -20.502336
# resetting env. episode reward total was -20.000000. running mean: -20.497313
# resetting env. episode reward total was -20.000000. running mean: -20.492340
# resetting env. episode reward total was -21.000000. running mean: -20.497416
# resetting env. episode reward total was -20.000000. running mean: -20.492442
# resetting env. episode reward total was -21.000000. running mean: -20.497518
# resetting env. episode reward total was -21.000000. running mean: -20.502543
# resetting env. episode reward total was -21.000000. running mean: -20.507517
# resetting env. episode reward total was -21.000000. running mean: -20.512442
# resetting env. episode reward total was -21.000000. running mean: -20.517318
# resetting env. episode reward total was -21.000000. running mean: -20.522144
# resetting env. episode reward total was -21.000000. running mean: -20.526923
# resetting env. episode reward total was -19.000000. running mean: -20.511654
# resetting env. episode reward total was -21.000000. running mean: -20.516537
# resetting env. episode reward total was -21.000000. running mean: -20.521372
# resetting env. episode reward total was -20.000000. running mean: -20.516158
# resetting env. episode reward total was -20.000000. running mean: -20.510997
# resetting env. episode reward total was -21.000000. running mean: -20.515887
# resetting env. episode reward total was -17.000000. running mean: -20.480728
# resetting env. episode reward total was -21.000000. running mean: -20.485920
# resetting env. episode reward total was -20.000000. running mean: -20.481061
# resetting env. episode reward total was -20.000000. running mean: -20.476251
# resetting env. episode reward total was -19.000000. running mean: -20.461488
# resetting env. episode reward total was -21.000000. running mean: -20.466873
# resetting env. episode reward total was -21.000000. running mean: -20.472205
# resetting env. episode reward total was -21.000000. running mean: -20.477482
# resetting env. episode reward total was -18.000000. running mean: -20.452708
# resetting env. episode reward total was -21.000000. running mean: -20.458181
# resetting env. episode reward total was -20.000000. running mean: -20.453599
# resetting env. episode reward total was -18.000000. running mean: -20.429063
# resetting env. episode reward total was -20.000000. running mean: -20.424772
# resetting env. episode reward total was -21.000000. running mean: -20.430524
# resetting env. episode reward total was -21.000000. running mean: -20.436219
# resetting env. episode reward total was -21.000000. running mean: -20.441857
# resetting env. episode reward total was -21.000000. running mean: -20.447438
# resetting env. episode reward total was -20.000000. running mean: -20.442964
# resetting env. episode reward total was -21.000000. running mean: -20.448534
# resetting env. episode reward total was -19.000000. running mean: -20.434049
# resetting env. episode reward total was -18.000000. running mean: -20.409709
# resetting env. episode reward total was -21.000000. running mean: -20.415611
# resetting env. episode reward total was -21.000000. running mean: -20.421455
# resetting env. episode reward total was -19.000000. running mean: -20.407241
# resetting env. episode reward total was -21.000000. running mean: -20.413168
# resetting env. episode reward total was -21.000000. running mean: -20.419037
# resetting env. episode reward total was -21.000000. running mean: -20.424846
# resetting env. episode reward total was -21.000000. running mean: -20.430598
# resetting env. episode reward total was -21.000000. running mean: -20.436292
# resetting env. episode reward total was -21.000000. running mean: -20.441929
# resetting env. episode reward total was -21.000000. running mean: -20.447510
# resetting env. episode reward total was -20.000000. running mean: -20.443035
# resetting env. episode reward total was -21.000000. running mean: -20.448604
# resetting env. episode reward total was -21.000000. running mean: -20.454118
# resetting env. episode reward total was -21.000000. running mean: -20.459577
# resetting env. episode reward total was -21.000000. running mean: -20.464981
# resetting env. episode reward total was -21.000000. running mean: -20.470331
# resetting env. episode reward total was -21.000000. running mean: -20.475628
# resetting env. episode reward total was -21.000000. running mean: -20.480872
# resetting env. episode reward total was -21.000000. running mean: -20.486063
# resetting env. episode reward total was -21.000000. running mean: -20.491202
# resetting env. episode reward total was -20.000000. running mean: -20.486290
# resetting env. episode reward total was -21.000000. running mean: -20.491428
# resetting env. episode reward total was -20.000000. running mean: -20.486513
# resetting env. episode reward total was -21.000000. running mean: -20.491648
# resetting env. episode reward total was -20.000000. running mean: -20.486732
# resetting env. episode reward total was -21.000000. running mean: -20.491864
# resetting env. episode reward total was -21.000000. running mean: -20.496946
# resetting env. episode reward total was -21.000000. running mean: -20.501976
# resetting env. episode reward total was -21.000000. running mean: -20.506956
# resetting env. episode reward total was -20.000000. running mean: -20.501887
# resetting env. episode reward total was -20.000000. running mean: -20.496868
# resetting env. episode reward total was -18.000000. running mean: -20.471899
# resetting env. episode reward total was -19.000000. running mean: -20.457180
# resetting env. episode reward total was -20.000000. running mean: -20.452609
# resetting env. episode reward total was -21.000000. running mean: -20.458082
# resetting env. episode reward total was -19.000000. running mean: -20.443502
# resetting env. episode reward total was -21.000000. running mean: -20.449067
# resetting env. episode reward total was -20.000000. running mean: -20.444576
# resetting env. episode reward total was -21.000000. running mean: -20.450130
# resetting env. episode reward total was -21.000000. running mean: -20.455629
# resetting env. episode reward total was -19.000000. running mean: -20.441073
# resetting env. episode reward total was -21.000000. running mean: -20.446662
# resetting env. episode reward total was -20.000000. running mean: -20.442195
# resetting env. episode reward total was -19.000000. running mean: -20.427773
# resetting env. episode reward total was -20.000000. running mean: -20.423496
# resetting env. episode reward total was -21.000000. running mean: -20.429261
# resetting env. episode reward total was -21.000000. running mean: -20.434968
# resetting env. episode reward total was -20.000000. running mean: -20.430618
# resetting env. episode reward total was -20.000000. running mean: -20.426312
# resetting env. episode reward total was -21.000000. running mean: -20.432049
# resetting env. episode reward total was -20.000000. running mean: -20.427729
# resetting env. episode reward total was -21.000000. running mean: -20.433451
# resetting env. episode reward total was -18.000000. running mean: -20.409117
# resetting env. episode reward total was -21.000000. running mean: -20.415026
# resetting env. episode reward total was -21.000000. running mean: -20.420875
# resetting env. episode reward total was -21.000000. running mean: -20.426667
# resetting env. episode reward total was -19.000000. running mean: -20.412400
# resetting env. episode reward total was -21.000000. running mean: -20.418276
# resetting env. episode reward total was -20.000000. running mean: -20.414093
# resetting env. episode reward total was -20.000000. running mean: -20.409952
# resetting env. episode reward total was -21.000000. running mean: -20.415853
# resetting env. episode reward total was -21.000000. running mean: -20.421694
# resetting env. episode reward total was -20.000000. running mean: -20.417477
# resetting env. episode reward total was -20.000000. running mean: -20.413302
# resetting env. episode reward total was -20.000000. running mean: -20.409169
# resetting env. episode reward total was -21.000000. running mean: -20.415078
# resetting env. episode reward total was -21.000000. running mean: -20.420927
# resetting env. episode reward total was -21.000000. running mean: -20.426718
# resetting env. episode reward total was -21.000000. running mean: -20.432451
# resetting env. episode reward total was -20.000000. running mean: -20.428126
# resetting env. episode reward total was -21.000000. running mean: -20.433845
# resetting env. episode reward total was -20.000000. running mean: -20.429506
# resetting env. episode reward total was -21.000000. running mean: -20.435211
# resetting env. episode reward total was -21.000000. running mean: -20.440859
# resetting env. episode reward total was -20.000000. running mean: -20.436451
# resetting env. episode reward total was -20.000000. running mean: -20.432086
# resetting env. episode reward total was -21.000000. running mean: -20.437765
# resetting env. episode reward total was -20.000000. running mean: -20.433388
# resetting env. episode reward total was -21.000000. running mean: -20.439054
# resetting env. episode reward total was -21.000000. running mean: -20.444663
# resetting env. episode reward total was -20.000000. running mean: -20.440216
# resetting env. episode reward total was -21.000000. running mean: -20.445814
# resetting env. episode reward total was -21.000000. running mean: -20.451356
# resetting env. episode reward total was -21.000000. running mean: -20.456843
# resetting env. episode reward total was -19.000000. running mean: -20.442274
# resetting env. episode reward total was -21.000000. running mean: -20.447851
# resetting env. episode reward total was -20.000000. running mean: -20.443373
# resetting env. episode reward total was -21.000000. running mean: -20.448939
# resetting env. episode reward total was -21.000000. running mean: -20.454450
# resetting env. episode reward total was -21.000000. running mean: -20.459905
# resetting env. episode reward total was -19.000000. running mean: -20.445306
# resetting env. episode reward total was -20.000000. running mean: -20.440853
# resetting env. episode reward total was -21.000000. running mean: -20.446445
# resetting env. episode reward total was -21.000000. running mean: -20.451980
# resetting env. episode reward total was -21.000000. running mean: -20.457460
